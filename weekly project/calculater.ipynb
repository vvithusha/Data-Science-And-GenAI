# %% [markdown]
# ###  calculater

# %%
import math

def show_menu():
    print("welcome to the CLI calculator!")
    print("1.addisition(+)")
    print("2.subraction (-)")
    print("3.multiplication (*)")
    print("4.divisition (/)")
    print("5.power(x^y)")
    print("6.square root(_/x)")
    print("7.trogonometry(sin,cos,tan)")
    print("8.modulus(%)")
    print("9.exit")
    print("======================")

def calculater():
    while True:
        show_menu()
        choice=input("çhoose an opreation(1-9)")
        
        if choice == "1":
            a=float(input("enter the number:"))
            b=float(input("enter the number"))
            print(f"addisition two number:{a+b}")

        elif choice == "2":
            a=float(input("enter the number:"))
            b=float(input("enter the number"))
            print(f"subraction two number:{a-b}") 

        elif choice == "3":
            a=float(input("enter the number:"))
            b=float(input("enter the number"))
            print(f"multipilication two number:{a*b}")

        elif choice == "4":
            a=float(input("enter the number:"))
            b=float(input("enter the number"))
            if b == 0:
                print("error can not divid o")
            else:
                print(f"divisition two number:{a/b}")

        elif choice == "5":
            a=float(input("enter the number:"))
            b=float(input("enter the number"))
            print(f"power two number:{a**b}")

        elif choice == "6":
            a=float(input("enter the number:"))
            if a >= 0:
                print(f"squareroot the number:{math.sqrt(a)}")   
            else:
                print("error can not divide negative number")

        elif choice == "7":
            angle = float(input("enter the angle:"))
            rad = math.radians(angle)
            ope=input("what you want to aperation(sin,cos,tan)")
            if ope == "sin":
                print(f"sin({angle}) = {math.sin(rad)}")
            elif ope == "cos":
                print(f"cos{angle} = {math.cos(rad)}")
            elif ope == "tan" :
                print(f"tan {angle} ={math.tan(rad)}")
            else:
                print("please input sin , cos , tan")  

        elif choice == "8":
            a=float(input("enter the number:"))
            b=float(input("enter the number:"))
            print(f"modulas two number:{a%b}")
        
        elif choice == "9":
            print("👋Exiting calculater. good buy!")
            break
        
        else:
            print("error input please enter valid input!")

calculater()
# Out:
# welcome to the CLI calculator!
# 1.addition(+)
# 2.subraction (-)
# 3.multiplication (*)
# 4.division (/)
# 5.power(x^y)
# 6.square root(_/x)
# 7.trogonometry(sin,cos,tan)
# 8.modulus(%)
# 9.exit
# ...
# multipilication two number:10.0
# welcome to the CLI calculator!
# 1.addition(+)
# 2.subraction (-)
# 3.multiplication (*)
# 4.division (/)
# 5.power(x^y)
# 6.square root(_/x)
# 7.trogonometry(sin,cos,tan)
# 8.modulus(%)
# 9.exit
# ...
# 👋exit this calculater good buy!

# %%
import math
while True:
    print("welcome to the CLI calculator!")
    choice = input("please enter the operation(add,sub,mul,div,pow,sqrt,trigo,mod,help,exit):")

    def add(a,b):
       if choice == "add" :
           return a + b
    def sub(a,b):
       if choice == "sub":
           return a-b
    def mul(a,b):
       if choice == "mul":
           return a*b
    def div(a,b):
       if choice == "div":
           return a/b
    def pow(a,b):
       if choice == "pow":
           return a**b
    def sqrt(a):
       if choice == "sqrt":
           return math.sqrt(a)
    def trigo():
       if choice == "trigo":
            angle = float(input("enter the angle:"))
            opp = input("what you want to operation(sin,cos,tan)")
            math.radians(angle)
            if opp == "sin":
                 return math.sin(angle)
            if opp == "cos":
                 return math.cos(angle)
            if opp == "tan":
                 return math.tan(angle)
            else:
                 return "please input sin,cos,tan"
    def mod(a,b):
       if choice == "mod":
           return a%b
    if choice.lower() == "help":
         print("1.add\n2.sub\n3.mul\n4.div\n5.pow\n6.sqrt\n7.trigo\n8.mod\n9.exit")
    if choice.lower() == "exit":
         print("exiting the calculater")
         break


    print(add(a,b))
    print(sub(a,b))
    print(mul(a,b))
    print(div(a,b))
    print(pow(a,b)) 
    print(sqrt(a))    
    print(trigo())
    print(mod(a,b))
    print("===================================")
# Out:
# welcome to the CLI calculator!
# exiting the calculater

# %%
import math

def add(a, b):
    return a + b

def sub(a, b):
    return a - b

def mul(a, b):
    return a * b

def div(a, b):
    if b == 0:
        return "Error: Division by zero!"
    return a / b

def power(a, b):
    return a ** b

def sqrt(a):
    return math.sqrt(a)

def mod(a, b):
    return a % b

def trigo():
    angle = float(input("Enter the angle (in degrees): "))
    opp = input("Which operation (sin, cos, tan): ").lower()
    rad = math.radians(angle)  # convert to radians
    if opp == "sin":
        return math.sin(rad)
    elif opp == "cos":
        return math.cos(rad)
    elif opp == "tan":
        return math.tan(rad)
    else:
        return "Invalid choice! Please choose sin, cos, or tan."

while True:
    print("\nWelcome to the CLI Calculator!")
    choice = input("Enter operation (add, sub, mul, div, pow, sqrt, trigo, mod, help, exit): ").lower()

    if choice == "help":
        print("Available operations:")
        print("1. add\n2. sub\n3. mul\n4. div\n5. pow\n6. sqrt\n7. trigo\n8. mod\n9. exit")
        continue

    if choice == "exit":
        print("Exiting the calculator... Goodbye!")
        break

    # Operations that need two numbers
    if choice in ["add", "sub", "mul", "div", "pow", "mod"]:
        a = float(input("Enter first number: "))
        b = float(input("Enter second number: "))

        if choice == "add":
            print("Result:", add(a, b))
        elif choice == "sub":
            print("Result:", sub(a, b))
        elif choice == "mul":
            print("Result:", mul(a, b))
        elif choice == "div":
            print("Result:", div(a, b))
        elif choice == "pow":
            print("Result:", power(a, b))
        elif choice == "mod":
            print("Result:", mod(a, b))

    # Operations with one number
    elif choice == "sqrt":
        a = float(input("Enter a number: "))
        print("Result:", sqrt(a))

    elif choice == "trigo":
        print("Result:", trigo())

    else:
        print("Invalid operation! Type 'help' to see available commands.")
# Out:
# Welcome to the CLI Calculator!
# Result: 115.0
#
# Welcome to the CLI Calculator!
# Result: 2025.0
#
# Welcome to the CLI Calculator!
# Exiting the calculator... Goodbye!
